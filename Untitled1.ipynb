# %% [markdown]
# <a href="https://colab.research.google.com/github/Astha-Rai/MarketPulsee/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ------------------------------------------
# 📌 Install dependencies
# ------------------------------------------
# !pip install yfinance transformers torch tensorflow scikit-learn matplotlib pandas

# ------------------------------------------
# 📌 Imports
# ------------------------------------------
import yfinance as yf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import torch

# ------------------------------------------
# 📌 Step 1: Download Stock Data
# ------------------------------------------
ticker = "AAPL"
df = yf.download(ticker, start="2020-01-01", end="2023-12-31")
data = df[['Close']]

plt.figure(figsize=(10,4))
plt.plot(data, label="Closing Price")
plt.legend()
plt.show()

# ------------------------------------------
# 📌 Step 2: Preprocess Data for LSTM
# ------------------------------------------
scaler = MinMaxScaler(feature_range=(0,1))
scaled_data = scaler.fit_transform(data)

train_size = int(len(scaled_data)*0.8)
train_data = scaled_data[:train_size]
test_data = scaled_data[train_size:]

def create_dataset(dataset, time_step=60):
    X, y = [], []
    for i in range(len(dataset)-time_step-1):
        X.append(dataset[i:(i+time_step), 0])
        y.append(dataset[i+time_step, 0])
    return np.array(X), np.array(y)

time_step = 60
X_train, y_train = create_dataset(train_data, time_step)
X_test, y_test = create_dataset(test_data, time_step)

X_train = X_train.reshape(X_train.shape[0], X_train.shape[1], 1)
X_test = X_test.reshape(X_test.shape[0], X_test.shape[1], 1)

# ------------------------------------------
# 📌 Step 3: Build & Train LSTM Model
# ------------------------------------------
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(60,1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

model.compile(optimizer="adam", loss="mean_squared_error")
model.fit(X_train, y_train, batch_size=32, epochs=5)

# Save model
model.save("marketpulse_model.keras")
print("✅ Model saved as marketpulse_model.keras")

# ------------------------------------------
# 📌 Step 4: Load FinBERT for Sentiment Analysis
# ------------------------------------------
finbert_model = AutoModelForSequenceClassification.from_pretrained("yiyanghkust/finbert-tone")
tokenizer = AutoTokenizer.from_pretrained("yiyanghkust/finbert-tone")

def analyze_sentiment(text):
    inputs = tokenizer(text, return_tensors="pt", truncation=True, padding=True)
    outputs = finbert_model(**inputs)
    scores = torch.nn.functional.softmax(outputs.logits, dim=1)
    labels = ["Negative", "Neutral", "Positive"]
    return dict(zip(labels, scores[0].detach().numpy()))

# Example test
sample_news = "Apple reports record-breaking iPhone sales in the last quarter."
print(analyze_sentiment(sample_news))
# Out:
# ...
# /tmp/ipython-input-451519464.py:23: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df = yf.download(ticker, start="2020-01-01", end="2023-12-31")
# [*********************100%***********************]  1 of 1 completed
# Epoch 1/5
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/rnn/rnn.py:199: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 6s 50ms/step - loss: 0.1190
# Epoch 2/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 49ms/step - loss: 0.0046
# Epoch 3/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 1s 50ms/step - loss: 0.0026
# Epoch 4/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 69ms/step - loss: 0.0020
# Epoch 5/5
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 0.0017
# ✅ Model saved as marketpulse_model.keras
# ...
